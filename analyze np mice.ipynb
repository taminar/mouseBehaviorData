# %%
from mouseBehavior import mouseBehaviorData as mbd
import numpy as np
import os, glob

# %%
mouseInfo = ('390339', '385531', '385533', '394873',
            '403472', '403468', '409096', '408528',
            '412624', '408527', '416576', '416656',
            '417882', '421323', '422856', '422699',
            '423749', '423750', '423744', '423745',
            '423746', '427937', '429083', '429084',
            '432291', '442594', '459521', '461027',
            '472392', '472395', '481531', '481356',
            '471727', '473189', '474732', '479219',
            '484106', '486622', '486635', '490193',
            '490194', '468670', '470005', '478202', 
            '477121', '473254', '477120', '487461', 
            '473248', '487460', '477810', '476815', 
            '485051', '489138', '495800', '492651', 
            '495662')

mouseInfo = np.unique(mouseInfo)

# %%
#checks to see if a mouse behavior object already exists for given mouse so it doesn't have to refetch data from the network
def checkforpickle(directory, mouseID):
    pkllist = [f for f in os.listdir(directory) if '.pkl' in f]
    mouseID = str(mouseID)
    pklpath = None
    for pkl in pkllist:
        if pkl[:6]==mouseID:
            pklpath = os.path.join(directory, pkl)
    return pklpath

# %%
#Directory where the mouse object pkls are stored
pkldir = r"\\allen\programs\braintv\workgroups\nc-ophys\corbettb\NP_behavior_pipeline\behavior_sessions\all np rigs"

#Directory where the dataframes summarizing behavior are stored (if saved separately)
dataframe_save_dir = r"\\allen\programs\braintv\workgroups\nc-ophys\corbettb\NP_behavior_pipeline\behavior_sessions\all np rigs\dataframes"

dflist = []
mouseids = []
for mouse in mouseInfo:
    if isinstance(mouseInfo[0], tuple):
        mouse = mouse[0]
    print(mouse)
    
    #First look to see if there's already a pkl file with this mouse' data
    pklpath = checkforpickle(pkldir, mouse)
    try:
        #get pkl if it already exists
        if pklpath is not None:
            print('reading from pkl')
            m = mbd()
            m.loadFromPickle(pklpath)
            m.add_weight_and_water_history()
            m.calculate_behavior_metrics()
            m.add_metadata_to_dataframe()

        #otherwise make a new one
        else:
            print('fetching data')
            m = mbd(mouse_id=mouse, daysBeforeHandoff=100)
            m.buildBehaviorDataframe(all_sessions=True)

        m.saveDirectory = pkldir
        m.saveToPickle()
        m.save_dataframe_separately(dataframe_save_dir)
        dflist.append(m.beh_df)
        mouseids.append(mouse)
    except Exception as e:
        print('failed to load data for mouse ' + mouse, e)
        continue
# Out:
# 385531
# fetching data
# ('failed to load data for mouse 385531', ValueError('Wrong number of items passed 0, placement implies 1',))
# 385533
# fetching data
# ('failed to load data for mouse 385533', ValueError('Wrong number of items passed 0, placement implies 1',))
# 390339
# fetching data
# ('failed to load data for mouse 390339', KeyError('items', u'occurred at index 4'))
# 394873
# fetching data
# ('Error loading //allen/programs/braintv/production/visualbehavior/prod0/specimen_737270308/behavior_session_737547971\\180815181441_394873_624521ab-0e8f-4f19-9a8d-6de7d285f008.pkl', IndexError('index 112835 is out of bounds for axis 0 with size 112834',))
# Did not find any water entries for this mouse
# 403468
# fetching data
# mouseBehavior.py:210: RuntimeWarning: invalid value encountered in divide
#   return responses/float(denom)
# mouseBehavior.py:169: RuntimeWarning: invalid value encountered in divide
#   faRate = trial_number_limit(fas/float(fas+crs), fas+crs)
# c:\users\svc_ccg\appdata\local\continuum\anaconda3\envs\lims\lib\site-packages\scipy\stats\_distn_infrastructure.py:1914: RuntimeWarning: invalid value encountered in greater
#   cond1 = (0 < q) & (q < 1)
# c:\users\svc_ccg\appdata\local\continuum\anaconda3\envs\lims\lib\site-packages\scipy\stats\_distn_infrastructure.py:1914: RuntimeWarning: invalid value encountered in less
#   cond1 = (0 < q) & (q < 1)
# c:\users\svc_ccg\appdata\local\continuum\anaconda3\envs\lims\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# 403472
# fetching data
# 408527
# fetching data
# c:\users\svc_ccg\appdata\local\continuum\anaconda3\envs\lims\lib\site-packages\visual_behavior-0.6.0.dev0-py2.7.egg\visual_behavior\translator\foraging2\extract_stimuli.py:106: UserWarning:
# there was no omitted_flash_frame_log, but long delays were present that were assumed to be omitted flashes
#   warnings.warn('\nthere was no omitted_flash_frame_log, but long delays were present that were assumed to be omitted flashes')
# 408528
# fetching data
# 409096
# fetching data
# 412624
# fetching data
# 416576
# fetching data
# 416656
# fetching data
# 417882
# fetching data
# 421323
# fetching data
# ('Error loading //allen/programs/braintv/production/visualbehavior/prod0/specimen_769292015/behavior_session_802955854\\190103102828_421323_8660934e-06a3-4f50-b0dd-e633a0d07700.pkl', IndexError('index 1207 is out of bounds for axis 0 with size 1206',))
# 422699
# fetching data
# 422856
# fetching data
# 423744
# fetching data
# 423745
# fetching data
# 423746
# fetching data
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_784187016/behavior_session_969732549\2955c30e64d148bd829dd4ca66fc7c06.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_784187016/behavior_session_969732549\2955c30e64d148bd829dd4ca66fc7c06.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_784187016/behavior_session_969682924\ef77930ace12446d81f052eab3302734.pkl
# 423749
# fetching data
# 423750
# fetching data
# 427937
# fetching data
# 429083
# fetching data
# 429084
# fetching data
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_791837237/behavior_session_914541095\28e2b4a865d14126a950ca97629a4bac.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_791837237/behavior_session_914541095\28e2b4a865d14126a950ca97629a4bac.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_791837237/behavior_session_914523820\18bdac393e1c4258a2d5d95c931f764e.pkl
# 432291
# fetching data
# 442594
# fetching data
# 459521
# fetching data
# 461027
# fetching data
# 468670
# fetching data
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_879130211/behavior_session_950813327\91a34c1f9e2b4c65853bb95873139577.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_879130211/behavior_session_950813327\91a34c1f9e2b4c65853bb95873139577.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_879130211/behavior_session_949613885\7b353477fb30495d98d33976e406f29d.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_879130211/behavior_session_949579776\de92125984464e209260007c20a9a0c7.pkl
# 470005
# fetching data
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_887093586/behavior_session_960913729\503f5cf1cbb64ee88a1af0b3b5c7e7f8.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_887093586/behavior_session_960913729\503f5cf1cbb64ee88a1af0b3b5c7e7f8.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_887093586/behavior_session_960888992\e3805fe85b244a26b5b94aca5681efbe.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_887093586/behavior_session_960237905\098eabe0b02d4b2d9d4c3863b4af2f36.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_887093586/behavior_session_960186051\dbb1f89f52304180b9acf6f9fdcf7b24.pkl
# 471727
# fetching data
# 472392
# fetching data
# 472395
# fetching data
# 473189
# fetching data
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_904924998/behavior_session_975514004\73a86daa6bd64e7293515ad19b4b6a00.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_904924998/behavior_session_975514004\73a86daa6bd64e7293515ad19b4b6a00.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_904924998/behavior_session_975502111\a128e9b7d4944d079a1351bfee43d2ff.pkl
# 473248
# fetching data
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_892343422/behavior_session_987203282\5954fcaa94e24a5298a111175fda0993.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_892343422/behavior_session_987203282\5954fcaa94e24a5298a111175fda0993.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_892343422/behavior_session_987150387\7a2fb53edf3b44c3b8cb9e4ace30e228.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_892343422/behavior_session_986321051\3d4582e9779b4988bcd8c45176477f3c.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_892343422/behavior_session_986266764\955c47b43f9e4ce9b0283797e122b2df.pkl
# 473254
# fetching data
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_893448041/behavior_session_977864592\3b17bb055d94486582f37556ab31e85b.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_893448041/behavior_session_977864592\3b17bb055d94486582f37556ab31e85b.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_893448041/behavior_session_977805472\7c0d2f9af9ad4a3ea330c53d76169ed2.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_893448041/behavior_session_977042411\b0bc1b74fddb4b3aae35ac709e0364d0.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_893448041/behavior_session_977006468\1fa47e06e70a4a639053f4e7c101a2af.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_893448041/behavior_session_976219228\5ac22286df384f83a4516c2d76f9ce3f.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_893448041/behavior_session_976195111\b13ae14ecb3c475c9a859348138f6af5.pkl
# 474732
# fetching data
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_910281273/behavior_session_995614971\7398d2a7ac9d41da822071d8db24f313.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_910281273/behavior_session_995614971\7398d2a7ac9d41da822071d8db24f313.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_910281273/behavior_session_995614969\49ee6afd56a1426a8e26b3aa0f8e5560.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_910281273/behavior_session_995424441\03746f6eddaf42309b09a968efbc7acb.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_910281273/behavior_session_995424438\3b751cd68d5f4bec9c82654713e02ba4.pkl
# 476815
# fetching data
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_908077422/behavior_session_1002294151\5ce59143c38d48379e8cebdad4d79722.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_908077422/behavior_session_1002294151\5ce59143c38d48379e8cebdad4d79722.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_908077422/behavior_session_1002285785\b806202674d2487e9ceabc8ff375d04b.pkl
# 477120
# fetching data
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_909823930/behavior_session_978234612\869869383cc54f9b94c592a60579d3ec.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_909823930/behavior_session_978234612\869869383cc54f9b94c592a60579d3ec.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_909823930/behavior_session_978213743\5aa390345d28425e97cf616721afa3cf.pkl
# 477121
# fetching data
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_909843780/behavior_session_972664758\ac33f860e6df439ea0a486a4e736912c.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_909843780/behavior_session_972664758\ac33f860e6df439ea0a486a4e736912c.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_909843780/behavior_session_972559349\ac7427f1729c453791919c6bb241afb2.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_909843780/behavior_session_972137597\911aa729c2d142ec988d34756bc8bf7e.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_909843780/behavior_session_972110529\f04f342ac76947f1a5dfa11af937ced8.pkl
# 477810
# fetching data
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_909590776/behavior_session_990649761\bdcf1665ad2643228f7412cfa59df61b.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_909590776/behavior_session_990649761\bdcf1665ad2643228f7412cfa59df61b.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_909590776/behavior_session_990635347\d757e950c9804d8f88228c9354b5bbc4.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_909590776/behavior_session_990362103\539482fb9b084463af2ad825e6b3e464.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_909590776/behavior_session_990351280\0790349756bb46e79d4c0c3f51c7e137.pkl
# 478202
# fetching data
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_904840105/behavior_session_969580742\b5fc188834484de289efbfb54ac85cb6.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_904840105/behavior_session_969580742\b5fc188834484de289efbfb54ac85cb6.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_904840105/behavior_session_969565244\df7a1d8d3f1e457d9a6cbc220ef891e0.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_904840105/behavior_session_968615544\852f3c8901494bf49cf89218ad48c5fd.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_904840105/behavior_session_968591093\72a5f4de8cb548baaaa39a079852860a.pkl
# ('Error loading //allen/programs/braintv/production/visualbehavior/prod0/specimen_904840105/behavior_session_931729317\\190826102740_478202_4f4b9c95-3fc7-4ab2-a759-064545e183aa.pkl', IndexError('index 218652 is out of bounds for axis 0 with size 218652',))
# 479219
# fetching data
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_917582932/behavior_session_990650365\b56dbe0de74b46ceb849345b202bb4b0.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_917582932/behavior_session_990650365\b56dbe0de74b46ceb849345b202bb4b0.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_917582932/behavior_session_990635954\a07a99f4bc974aa6a24a90f9d0d9e1bb.pkl
# 481356
# fetching data
# 481531
# fetching data
# ('failed to load data for mouse 481531', TypeError("'NoneType' object has no attribute '__getitem__'",))
# 484106
# fetching data
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_931903393/behavior_session_994237982\c2d95a29259045c493df8dbf683b7510.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_931903393/behavior_session_994237982\c2d95a29259045c493df8dbf683b7510.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_931903393/behavior_session_994231361\45befab23db644c0b03af1b991401173.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_931903393/behavior_session_994042789\a39ff91712f243428dc0a4a7040a8ca8.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_931903393/behavior_session_994042784\fdc0018c808b4779a1e03bf3ba417337.pkl
# 485051
# fetching data
# 486622
# fetching data
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_935558114/behavior_session_1004108005\74aa4251268140a6964100e2e90d49fd.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_935558114/behavior_session_1004108005\74aa4251268140a6964100e2e90d49fd.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_935558114/behavior_session_1004108003\324138e04af54142834941ff5112c30c.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_935558114/behavior_session_1003744890\6ee853e40eb54b12abfaece2875023b6.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_935558114/behavior_session_1003704504\eef47f4925d84587af475018c3a76797.pkl
# 486635
# fetching data
# 487460
# fetching data
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_941629777/behavior_session_982823792\551c2f287b074797b9cd3f5d4fdc7297.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_941629777/behavior_session_982823792\551c2f287b074797b9cd3f5d4fdc7297.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_941629777/behavior_session_982745523\5310e99712fe4747a62001ada2f6d96a.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_941629777/behavior_session_982059432\ac0867cc2972410c8782ab21eb9ae52b.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_941629777/behavior_session_982009411\a3828b6f1ab94da5a63405cc2c3183a7.pkl
# 487461
# fetching data
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_940732891/behavior_session_989163718\cecf82fc998f47cebb80f8b3571bd6fb.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_940732891/behavior_session_989163718\cecf82fc998f47cebb80f8b3571bd6fb.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_940732891/behavior_session_989140241\ff93d726a1894982970517528cac0ce9.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_940732891/behavior_session_988253253\aa6d4e4971594702ab2c0197d5494cdb.pkl
# Found non-behavior pickle file: //allen/programs/braintv/production/visualbehavior/prod0/specimen_940732891/behavior_session_988177938\ee579b33de9b4b41b9374c66d18d8a04.pkl
# 489138
# fetching data
# 490193
# fetching data
# 490194
# fetching data
# 492651
# fetching data
# 495662
# fetching data
# 495800
# fetching data

# %% [markdown]
# save population df with all mice concatenated

# %%
import pandas as pd
popdf = pd.concat(dflist, keys=mouseids)
# Out:
# c:\users\svc_ccg\appdata\local\continuum\anaconda3\envs\lims\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
# get mice that have transitioned to lower reward volumes
popdf['session_duration'] = popdf.apply(lambda row: row['trials']['session_duration'][0], axis=1)
lowVol = (popdf['reward_volume'] == 0.005) & (popdf['session_datetime_utc']>'2019')
lowVol_mice = popdf.loc[lowVol].index.get_level_values(0).unique()
lvdf = popdf.loc[lowVol_mice]
lvdf = lvdf.loc[lvdf['session_duration']>2000]

lvdf[['reward_volume', 'stage', 'session_duration']]
# Out:
#            reward_volume                                         stage  \
# 422699 0           0.005                              EPHYS_1_images_B
#        1           0.005                              EPHYS_1_images_A
#        2           0.007             TRAINING_4_images_A_handoff_ready
#        3           0.007             TRAINING_4_images_A_handoff_ready
#        4           0.007             TRAINING_4_images_A_handoff_ready
#        5           0.007             TRAINING_4_images_A_handoff_ready
#        6           0.007             TRAINING_4_images_A_handoff_ready
#        7           0.007             TRAINING_4_images_A_handoff_ready
#        8           0.007            TRAINING_4_images_A_handoff_lapsed
#        9           0.007            TRAINING_4_images_A_handoff_lapsed
#        10          0.007            TRAINING_4_images_A_handoff_lapsed
#        11          0.007             TRAINING_4_images_A_handoff_ready
#        12          0.007             TRAINING_4_images_A_handoff_ready
#        13          0.007             TRAINING_4_images_A_handoff_ready
#        14          0.007             TRAINING_4_images_A_handoff_ready
#        15          0.007            TRAINING_4_images_A_handoff_lapsed
#        16          0.007            TRAINING_4_images_A_handoff_lapsed
#        17          0.007            TRAINING_4_images_A_handoff_lapsed
#        18          0.007             TRAINING_4_images_A_handoff_ready
#        19          0.007             TRAINING_4_images_A_handoff_ready
#        20          0.007             TRAINING_4_images_A_handoff_ready
#        21          0.007             TRAINING_4_images_A_handoff_ready
#        22          0.007             TRAINING_4_images_A_handoff_ready
#        23          0.007             TRAINING_4_images_A_handoff_ready
#        24          0.007             TRAINING_4_images_A_handoff_ready
#        25          0.007             TRAINING_4_images_A_handoff_ready
#        26          0.007             TRAINING_4_images_A_handoff_ready
#        27          0.007             TRAINING_4_images_A_handoff_ready
#        28          0.007             TRAINING_4_images_A_handoff_ready
#        29          0.007             TRAINING_4_images_A_handoff_ready
# ...                  ...                                           ...
# 495662 22          0.010                   TRAINING_2_gratings_flashed
#        23          0.010                   TRAINING_2_gratings_flashed
#        24          0.010                   TRAINING_2_gratings_flashed
#        25          0.010                           TRAINING_1_gratings
#        26          0.010                           TRAINING_1_gratings
#        27          0.010                           TRAINING_1_gratings
#        28          0.010                           TRAINING_1_gratings
#        29          0.010                           TRAINING_1_gratings
# 495800 0           0.003                   EPHYS_1_images_B_5uL_reward
#        1           0.005  TRAINING_4_images_A_handoff_ready_low_volume
#        2           0.005  TRAINING_4_images_A_handoff_ready_low_volume
#        3           0.005  TRAINING_4_images_A_handoff_ready_low_volume
#        4           0.005  TRAINING_4_images_A_handoff_ready_low_volume
#        5           0.005  TRAINING_4_images_A_handoff_ready_low_volume
#        6           0.005  TRAINING_4_images_A_handoff_ready_low_volume
#        7           0.005  TRAINING_4_images_A_handoff_ready_low_volume
#        8           0.005  TRAINING_4_images_A_handoff_ready_low_volume
#        9           0.007             TRAINING_5_images_A_handoff_ready
#        10          0.007             TRAINING_5_images_A_handoff_ready
#        11          0.007             TRAINING_5_images_A_handoff_ready
#        12          0.007                  TRAINING_5_images_A_epilogue
#        13          0.007                  TRAINING_4_images_A_training
#        14          0.010               TRAINING_3_images_A_10uL_reward
#        15          0.010               TRAINING_3_images_A_10uL_reward
#        16          0.010               TRAINING_3_images_A_10uL_reward
#        17          0.010                   TRAINING_2_gratings_flashed
#        18          0.010                           TRAINING_1_gratings
#        19          0.010                           TRAINING_1_gratings
#        20          0.010                           TRAINING_1_gratings
#        21          0.010                           TRAINING_1_gratings
#
#            session_duration
# 422699 0        3642.274912
#        1        3646.782069
#        2        3643.105337
#        3        3640.207857
#        4        3647.546537
#        5        3643.911474
#        6        3640.089781
#        7        3643.833721
#        8        3646.446577
#        9        3642.091810
#        10       3650.837027
#        11       3641.960339
#        12       3642.935991
#        13       3643.843136
#        14       3648.597380
#        15       3644.531866
#        16       3640.339596
#        17       3643.132075
#        18       3640.836028
#        19       3642.298036
#        20       3643.305549
#        21       3645.987915
#        22       3641.101936
#        23       3640.817236
#        24       3640.824366
#        25       3640.153909
#        26       3644.328047
#        27       3647.466912
#        28       3640.884243
#        29       3641.567119
# ...                     ...
# 495662 22       3642.343478
#        23       3650.434942
#        24       3644.390614
#        25       3643.117596
#        26       3648.093984
#        27       3644.773413
#        28       3641.356646
#        29       3639.955939
# 495800 0        3606.264507
#        1        3649.917664
#        2        3646.665865
#        3        3642.262947
#        4        3641.143816
#        5        3644.846272
#        6        3642.111128
#        7        3640.610105
#        8        3641.178768
#        9        4505.837652
#        10       4505.117883
#        11       4509.385130
#        12       4501.044857
#        13       3643.674061
#        14       3647.380736
#        15       3640.246312
#        16       3645.921670
#        17       3647.603054
#        18       3641.582564
#        19       3642.156947
#        20       3651.737411
#        21       3640.341851
#
# [2670 rows x 3 columns]

# %%
from matplotlib import pyplot as plt
# example rig by rig analysis
handoffready = lvdf['stage'].str.contains('TRAINING_5_images_A_handoff_ready')
hrdf = lvdf.loc[handoffready]

rig_rewards = hrdf.groupby(by='rig').mean()['earned_rewards']
rig_dprime = hrdf.groupby(by='rig').mean()['engaged_dprime']

rigs = hrdf.groupby(by='rig').mean().index.to_list()
fig, ax = plt.subplots()
#ax.plot(hrdf.groupby(by='session_day_of_week').mean()['earned_rewards'])
ax.errorbar(np.arange(len(rig_rewards)), rig_rewards, yerr=hrdf.groupby(by='rig').sem()['earned_rewards'])
ax.set_xlabel('rig ID')
ax.set_ylabel('rewards earned in handoff ready')

ax.set_xticks(np.arange(len(rigs)))
ax.set_xticklabels(rigs)

hrdf.groupby('rig')['id'].count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-16beb1fb3a13> in <module>()
#       1 from matplotlib import pyplot as plt
#       2 # example rig by rig analysis
# ----> 3 handoffready = lvdf['stage'].str.contains('TRAINING_5_images_A_handoff_ready')
#       4 hrdf = lvdf.loc[handoffready]
#       5
#
# NameError: name 'lvdf' is not defined
