# %%
from mouseBehavior import mouseBehaviorData as mbd
from matplotlib import pyplot as plt
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# **get data from lims for one mouse**

# %%
m = mbd(mouse_id='390339', daysBeforeHandoff=100)
m.getBehaviorSessionsForMouse()

# %%
m.behavior_sessions #list of all behavior sessions
# Out:
#            id behavior_training_id                 created_at  \
# 0   739119010                 None 2018-08-18 01:30:56.547494
# 1   737547971                 None 2018-08-16 01:50:55.698498
# 2   739871053                 None 2018-08-21 01:40:55.280989
# 3   740417007                 None 2018-08-22 00:20:53.893888
# 4   742089251                 None 2018-08-25 01:37:17.345836
# 5   743148521                 None 2018-08-29 01:50:52.030295
# 6   742806688                 None 2018-08-28 01:50:58.734074
# 7   740895635                 None 2018-08-23 01:37:02.547039
# 8   745392716                 None 2018-09-05 00:55:54.805065
# 9   745823386                 None 2018-09-06 01:15:54.961091
# 10  750786953                 None 2018-09-11 21:56:28.054942
# 11  752340227                 None 2018-09-13 00:20:55.841675
# 12  754970740                 None 2018-09-19 01:10:51.082135
# 13  755601356                 None 2018-09-19 22:25:51.768119
# ...

# %%
m.buildBehaviorDataframe(all_sessions=True) #This is the step that actually pulls the data. Default is to pull from self.daysBeforeHandoff to present, but you can also specify start and end dates
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-7679c2640a1e> in <module>()
# ----> 1 m.buildBehaviorDataframe(all_sessions=True) #This is the step that actually pulls the data. Default is to pull from self.daysBeforeHandoff to present, but you can also specify start and end dates
#
# C:\Users\svc_ccg\Documents\GitHub\mouseBehaviorData\mouseBehavior.pyc in buildBehaviorDataframe(self, startDate, endDate, all_sessions, overwrite_behdf)
#     174         if not hasattr(self, 'beh_df') or overwrite_behdf:
#     175             toAnalyze = self.behavior_sessions[(self.behavior_sessions['created_at']>=startDate)&(self.behavior_sessions['created_at']<endDate)]
# --> 176             toAnalyze['trials'] = toAnalyze.apply(lambda row: self.getTrialsDF(row['pklfile']), axis=1) #this trials object has all the info you need about the session
#     177
# ...

# %%
m.beh_df  #full dataframe on the selected dates
# Out:
#            id behavior_training_id                 created_at  \
# 1   991960159                 None 2019-12-03 19:06:00.668338
# 2   991678908                 None 2019-12-02 18:50:57.094873
# 3   990849308                 None 2019-11-27 20:00:55.792005
# 4   990516898                 None 2019-11-26 18:51:00.752719
# 5   990263714                 None 2019-11-25 20:20:59.549290
# 6   989409146                 None 2019-11-22 20:05:58.495720
# 7   989040717                 None 2019-11-21 20:26:05.086158
# 8   986810550                 None 2019-11-19 19:16:02.680177
# 9   985840683                 None 2019-11-18 18:55:57.554801
# 10  983570154                 None 2019-11-15 20:10:56.559143
# 11  982537745                 None 2019-11-14 18:31:00.205927
# 12  981693185                 None 2019-11-13 18:41:05.272156
# 13  979260021                 None 2019-11-11 19:15:54.848891
# 14  978708143                 None 2019-11-08 20:56:01.548036
# ...

# %%
m.saveDirectory = r"\\allen\programs\braintv\workgroups\nc-ophys\corbettb\NP_behavior_pipeline\behavior_sessions"
m.saveToPickle() #save object to network so we don't have to make it from the original pickles again

# %%
# %matplotlib notebook
m.plotSessionHistory()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mm = mbd() #make new object and load in the data we just saved
mm.loadFromPickle(r"\\allen\programs\braintv\workgroups\nc-ophys\corbettb\NP_behavior_pipeline\behavior_sessions\403472_behaviorHistory.pkl")
mm.buildBehaviorDataframe(all_sessions=True)
# Out:
# mouseBehavior.py:130: RuntimeWarning: invalid value encountered in divide
#   engagedTrialFARate = fas/float(fas+crs)
# c:\anaconda2\envs\lims\lib\site-packages\scipy\stats\_distn_infrastructure.py:1914: RuntimeWarning: invalid value encountered in greater
#   cond1 = (0 < q) & (q < 1)
# c:\anaconda2\envs\lims\lib\site-packages\scipy\stats\_distn_infrastructure.py:1914: RuntimeWarning: invalid value encountered in less
#   cond1 = (0 < q) & (q < 1)

# %%
mm.plotSessionHistory()
# Out:
# c:\anaconda2\envs\lims\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
# %matplotlib notebook
mm.plotPerformanceByTimeFromLastSession()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mm.beh_df
# Out:
#            id behavior_training_id                 created_at  \
# 33  772128766                 None 2018-11-02 02:45:49.566888
# 32  771429774                 None 2018-11-01 00:05:55.590802
# 31  770243700                 None 2018-10-30 21:05:49.173118
# 30  770036348                 None 2018-10-29 23:45:59.354045
# 29  769510603                 None 2018-10-27 00:20:54.226692
# 27  768857275                 None 2018-10-26 00:20:49.644332
# 26  768192694                 None 2018-10-25 00:00:57.461074
# 24  767357303                 None 2018-10-23 23:50:55.177697
# 28  766760600                 None 2018-10-22 23:10:51.535990
# 25  766752673                 None 2018-10-22 22:05:54.943342
# 23  766195162                 None 2018-10-19 23:26:02.661307
# 22  765428696                 None 2018-10-19 03:10:49.634182
# 21  764925990                 None 2018-10-17 23:40:54.090711
# 20  764508503                 None 2018-10-17 00:10:51.674920
# ...

# %%
mm.beh_df = mm.beh_df.sort_values('session_datetime_utc', ascending=False)
mm.beh_df
# Out:
#            id behavior_training_id                 created_at  \
# 33  772128766                 None 2018-11-02 02:45:49.566888
# 32  771429774                 None 2018-11-01 00:05:55.590802
# 31  770243700                 None 2018-10-30 21:05:49.173118
# 30  770036348                 None 2018-10-29 23:45:59.354045
# 29  769510603                 None 2018-10-27 00:20:54.226692
# 27  768857275                 None 2018-10-26 00:20:49.644332
# 26  768192694                 None 2018-10-25 00:00:57.461074
# 24  767357303                 None 2018-10-23 23:50:55.177697
# 28  766760600                 None 2018-10-22 23:10:51.535990
# 25  766752673                 None 2018-10-22 22:05:54.943342
# 23  766195162                 None 2018-10-19 23:26:02.661307
# 22  765428696                 None 2018-10-19 03:10:49.634182
# 21  764925990                 None 2018-10-17 23:40:54.090711
# 20  764508503                 None 2018-10-17 00:10:51.674920
# ...
